# %% [markdown]
# # Salt and Pepper Experiments

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
from images_generator import salt_and_pepper_noise, normalize_img_to_0_255, generate_histogram

# %%
images_class = 'Woody'
images_path = f'data/Normalized_Brodatz/{images_class}'
image_name = 'D69'
image_title = f'{images_class}-{image_name}'
gs_image = cv2.imread(f'{images_path}/{image_name}.tif', cv2.IMREAD_GRAYSCALE)
if gs_image is not None:
    plt.imshow(gs_image, cmap='gray')
    plt.title(f"Imagem {image_title}")
    plt.axis('off')  # Remove os eixos
    plt.show()
else:
    print('error')

# %% [markdown]
# 30%

# %%
salt_prob=0.3
pepper_prob=0.3
# prob(127) = 1 - (salt_prob=0.3 + pepper_prob)

# Generate the 2D Hénon map data
image_3_3_4 = salt_and_pepper_noise(salt_prob, pepper_prob, gs_image)

# Plot the results
plt.clf()
plt.figure(1,figsize=(12, 8))
plt.imshow(image_3_3_4, cmap='gray')
plt.title(f'{image_title} S&P 30%')
plt.axis('off')  # Remove os eixos
plt.savefig(f'results/salt_and_pepper_noise/{image_title}_salt_{salt_prob}_pepper_{pepper_prob}.png')

# %%
salt_prob=0.05
pepper_prob=0.05
# prob(127) = 1 - (salt_prob=0.3 + pepper_prob)

# Generate the 2D Hénon map data
image_05_05_9 = salt_and_pepper_noise(salt_prob, pepper_prob, gs_image)

# Plot the results
plt.clf()
plt.figure(1,figsize=(12, 8))
plt.imshow(image_05_05_9, cmap='gray')
plt.title(f'{image_title} S&P 5%')
plt.axis('off')  # Remove os eixos
plt.savefig(f'results/salt_and_pepper_noise/{image_title}_salt_{salt_prob}_pepper_{pepper_prob}.png')

# %%
generate_histogram(image_3_3_4, isNormalized=True, title=f'{image_title} S&P 30%')
plt.savefig(f'results/salt_and_pepper_noise/{image_title}_salt_0.3_pepper_0.3_histogram.png')

# %%
generate_histogram(image_05_05_9, isNormalized=True, title=f'{image_title} S&P 5%')
plt.savefig(f'results/salt_and_pepper_noise/{image_title}_salt_0.05_pepper_0.05_histogram.png')

# %% [markdown]
# ## Generating data for the images

# %%
from experiments_functions import get_img_info

# %%
image_title = 'Woody-D69'
image_3_3_4_data = get_img_info(image_3_3_4, q_linspace = np.linspace(-2, 20, num = 221))
image_3_3_4_data.head(5)
image_3_3_4_data.to_csv(f"results/salt_and_pepper_noise/{image_title}_salt_0.3_pepper_0.3.csv", index = False)
# Out:
# q = -2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:624: RuntimeWarning: divide by zero encountered in power
#   weights                   = np.power(partitions.var(axis=1), q/2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:630: RuntimeWarning: invalid value encountered in divide
#   probabilities = total_variance_per_symbol/total_variance_per_symbol.sum()
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: divide by zero encountered in log
#   s_of_p_over_2 = -np.sum(probabilities*np.log(probabilities))/2
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: invalid value encountered in multiply
# ...

# %%
image_05_05_9_data = get_img_info(image_05_05_9, q_linspace = np.linspace(-2, 20, num = 221))
image_05_05_9_data.head(5)
image_05_05_9_data.to_csv(f"results/salt_and_pepper_noise/{image_title}_salt_0.05_pepper_0.05.csv", index = False)
# Out:
# q = -2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# ...

# %% [markdown]
# ## Generating both planes

# %%
image_title = 'Woody-D69'
image_05_05_9_data = pd.read_csv(f"results/salt_and_pepper_noise/{image_title}_salt_0.05_pepper_0.05.csv")
image_3_3_4_data = pd.read_csv(f"results/salt_and_pepper_noise/{image_title}_salt_0.3_pepper_0.3.csv")

# %%
for salt_p, pepper_p, data_ss in [('0.05', '0.05', image_05_05_9_data), ('0.3', '0.3', image_3_3_4_data)]:
    # SMOOTHNESS
    plt.figure(1)
    plt.clf() # clears the figure
    plt.rcParams.update({"font.size": 14})
    scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
    # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
    special_symbols = {0: 'o', 1: 's', 2: '^'}
    for q_value, marker in special_symbols.items():
        subset = data_ss[data_ss['q'] == q_value]
        plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')

    plt.colorbar(scatter, label='Parameter q')
    # plt.ylim([0, 1])
    # plt.xlim([0, 1])
    plt.ylim([-1, 1])
    plt.xlim([-1, 1])
    plt.grid()
    plt.xlabel('Smoothness')
    plt.ylabel('Curve structure')
    plt.title(f'SC {image_title} S&P {pepper_p}')

    plt.savefig(f'results/salt_and_pepper_noise/planes/{image_title}_SCplane_weighted_salt_{salt_p}_pepper_{pepper_p}.png')
            
    # CECP
    plt.figure(2)
    plt.clf() # clears the figure
    plt.rcParams.update({"font.size": 17})
    scatter = plt.scatter(data_ss['Weighted Entropy Correct'], data_ss['Weighted Complexity Correct'], c=data_ss['q'], cmap='gist_rainbow')
    # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
    special_symbols = {0: 'o', 1: 's', 2: '^'}
    for q_value, marker in special_symbols.items():
        subset = data_ss[data_ss['q'] == q_value]
        plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
    plt.colorbar(scatter, label='Parameter q')
    # plt.ylim([0, 1])
    # plt.xlim([0, 1])
    plt.ylim([-1, 1])
    plt.xlim([-1, 1])
    plt.grid()
    plt.xlabel('Weighted Entropy')
    plt.ylabel('Weighted Complexity')
    plt.title(f'CECP {image_title} S&P {pepper_p}')

    plt.savefig(f'results/salt_and_pepper_noise/planes/{image_title}_CECPplane_weighted_salt_{salt_p}_pepper_{pepper_p}.png')
    plt.clf() # clears the figure

# %% [markdown]
# ## Plotting the probabilities
