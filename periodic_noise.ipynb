# %% [markdown]
# # Periodic Noise Experiments

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
from utils.images_generator import periodic_noise, normalize_img_to_0_255, generate_histogram

# %%
images_class = 'Woody'
images_path = f'data/Normalized_Brodatz/{images_class}'
image_name = 'D69'
image_title = f'{images_class}-{image_name}'
gs_image = cv2.imread(f'{images_path}/{image_name}.tif', cv2.IMREAD_GRAYSCALE)
if gs_image is not None:
    plt.imshow(gs_image, cmap='gray')
    plt.title(f"Imagem {image_title}")
    plt.axis('off')  # Remove os eixos
    plt.show()
else:
    print('error')

# %%
plt.clf()
generate_histogram(gs_image, isNormalized=True, title=f'{image_title}')

# %%
freq_x = 20
freq_y = 50
amp = 50
# periodic_image = periodic_noise(0.8, 0.5, 3, gs_image)
periodic_image = periodic_noise(freq_x, freq_y, amp, gs_image)

# Plot the results
plt.clf()
plt.figure(1,figsize=(12, 8))
plt.imshow(periodic_image, cmap='gray')
plt.title(f'{image_title} Periodic fx {freq_x} fy {freq_y} a {amp}')
plt.axis('off')  # Remove os eixos
plt.savefig(f'results/periodic_noise/{image_title}.png', bbox_inches='tight')

# %%
plt.clf()
generate_histogram(periodic_image, isNormalized=True, title=f'{image_title} Periodic fx {freq_x} fy {freq_y} a {amp}')
plt.savefig(f'results/periodic_noise/{image_title}_{freq_x}_{freq_y}_{amp}_histogram.png', bbox_inches='tight')

# %% [markdown]
# ## Generating data for the images

# %%
from utils.experiments_functions import get_img_info

# %%
image_title = 'Woody-D69'
image_20_50_50_data = get_img_info(periodic_image, q_linspace = np.linspace(-2, 20, num = 221))
image_20_50_50_data.head(5)
image_20_50_50_data.to_csv(f"results/periodic_noise/{image_title}_20_50_50.csv", index = False)
# Out:
# q = -2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:624: RuntimeWarning: divide by zero encountered in power
#   weights                   = np.power(partitions.var(axis=1), q/2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:630: RuntimeWarning: invalid value encountered in divide
#   probabilities = total_variance_per_symbol/total_variance_per_symbol.sum()
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: divide by zero encountered in log
#   s_of_p_over_2 = -np.sum(probabilities*np.log(probabilities))/2
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: invalid value encountered in multiply
#   s_of_p_over_2 = -np.sum(probabilities*np.log(probabilities))/2
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.2999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.8999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.7999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.5999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.3999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.2999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.19999999999999996
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.09999999999999987
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = 0.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9267634229702962; Complexity Measure = 0.08728000781706528;
# q = 0.10000000000000009
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9369787123720407; Complexity Measure = 0.07892123570835641;
# q = 0.20000000000000018
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9337144162227249; Complexity Measure = 0.0827498179387056;
# q = 0.30000000000000027
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9302974061682113; Complexity Measure = 0.08670046725675519;
# q = 0.40000000000000036
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9267441181621368; Complexity Measure = 0.09075331486600346;
# q = 0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9230676958429472; Complexity Measure = 0.09489220393325558;
# q = 0.6000000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.919279141118059; Complexity Measure = 0.09910343145903364;
# q = 0.7000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9153880705996674; Complexity Measure = 0.1033749243933019;
# q = 0.8000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9114032026526826; Complexity Measure = 0.10769571407487583;
# q = 0.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9073326632654235; Complexity Measure = 0.11205561126262956;
# q = 1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9031841719316934; Complexity Measure = 0.11644501327876343;
# q = 1.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.898965149369659; Complexity Measure = 0.12085479622200636;
# q = 1.2000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.894682775322409; Complexity Measure = 0.12527626045998444;
# q = 1.3000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8903440153051217; Complexity Measure = 0.12970110823483175;
# q = 1.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8859556287586587; Complexity Measure = 0.13412143950377725;
# q = 1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8815241667347818; Complexity Measure = 0.1385297570746059;
# q = 1.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8770559643270656; Complexity Measure = 0.14291897540765233;
# q = 1.7000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8725571311204875; Complexity Measure = 0.14728242965577845;
# q = 1.8000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8680335416482103; Complexity Measure = 0.15161388296012093;
# q = 1.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8634908270017628; Complexity Measure = 0.15590753095886378;
# q = 2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8589343681949346; Complexity Measure = 0.16015800306685932;
# q = 2.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8543692915336779; Complexity Measure = 0.16436036045904476;
# q = 2.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8498004660277795; Complexity Measure = 0.16851009091672317;
# q = 2.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8452325027504155; Complexity Measure = 0.17260310082397914;
# q = 2.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8406697559790314; Complexity Measure = 0.17663570466614115;
# q = 2.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8361163259152554; Complexity Measure = 0.18060461240591488;
# q = 2.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.831576062769398; Complexity Measure = 0.18450691511093792;
# q = 2.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8270525719975756; Complexity Measure = 0.18834006918899943;
# q = 2.8000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8225492204907069; Complexity Measure = 0.19210187956078711;
# q = 2.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8180691435306567; Complexity Measure = 0.19579048206906816;
# q = 3.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8136152523470845; Complexity Measure = 0.19940432539057332;
# q = 3.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8091902421274526; Complexity Measure = 0.20294215268433977;
# q = 3.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8047966003511375; Complexity Measure = 0.20640298317900108;
# q = 3.3000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8004366153360454; Complexity Measure = 0.20978609387221267;
# q = 3.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7961123849022185; Complexity Measure = 0.21309100148832325;
# q = 3.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7918258250714921; Complexity Measure = 0.2163174448158314;
# q = 3.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.78757867873526; Complexity Measure = 0.2194653675240525;
# q = 3.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7833725242338996; Complexity Measure = 0.22253490153865427;
# q = 3.8000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7792087838014549; Complexity Measure = 0.22552635103834615;
# q = 3.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.775088731837912; Complexity Measure = 0.22844017711964762;
# q = 4.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7710135029789356; Complexity Measure = 0.2312769831633692;
# q = 4.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7669840999394028; Complexity Measure = 0.23403750092490277;
# q = 4.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7630014011125936; Complexity Measure = 0.23672257736050342;
# q = 4.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.759066167911589; Complexity Measure = 0.23933316219334846;
# q = 4.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7551790518434025; Complexity Measure = 0.24187029621601092;
# q = 4.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7513406013097242; Complexity Measure = 0.24433510032006595;
# q = 4.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7475512681309637; Complexity Measure = 0.24672876523862156;
# q = 4.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7438114137926404; Complexity Measure = 0.24905254198358867;
# q = 4.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7401213154151253; Complexity Measure = 0.25130773295629105;
# q = 4.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7364811714493665; Complexity Measure = 0.25349568370754244;
# q = 5.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.73289110710257; Complexity Measure = 0.25561777532143953;
# q = 5.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7293511794989049; Complexity Measure = 0.25767541739574357;
# q = 5.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7258613825811938; Complexity Measure = 0.2596700415908582;
# q = 5.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7224216517602564; Complexity Measure = 0.2616030957188806;
# q = 5.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7190318683191458; Complexity Measure = 0.263476038344039;
# q = 5.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7156918635799432; Complexity Measure = 0.2652903338659189;
# q = 5.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7124014228411105; Complexity Measure = 0.2670474480572356;
# q = 5.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7091602890936205; Complexity Measure = 0.268748844028408;
# q = 5.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7059681665242457; Complexity Measure = 0.27039597859191555;
# q = 5.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.702824723814457; Complexity Measure = 0.2719902990001743;
# q = 6.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6997295972434153; Complexity Measure = 0.27353324003163604;
# q = 6.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.696682393603501; Complexity Measure = 0.2750262214007285;
# q = 6.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6936826929367614; Complexity Measure = 0.2764706454683596;
# q = 6.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6907300511005388; Complexity Measure = 0.27786789523070815;
# q = 6.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6878240021704065; Complexity Measure = 0.27921933256517134;
# q = 6.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6849640606883715; Complexity Measure = 0.2805262967133901;
# q = 6.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6821497237641063; Complexity Measure = 0.2817901029824017;
# q = 6.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.679380473036772; Complexity Measure = 0.2830120416460177;
# q = 6.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6766557765047673; Complexity Measure = 0.2841933770296098;
# q = 6.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6739750902305012; Complexity Measure = 0.28533534676250827;
# q = 7.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6713378599270474; Complexity Measure = 0.28643916118321583;
# q = 7.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6687435224332845; Complexity Measure = 0.28750600288361544;
# q = 7.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6661915070838723; Complexity Measure = 0.28853702637927636;
# q = 7.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6636812369801577; Complexity Measure = 0.2895333578938522;
# q = 7.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.661212130167843; Complexity Measure = 0.29049609524641357;
# q = 7.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.658783600726998; Complexity Measure = 0.2914263078313661;
# q = 7.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6563950597797353; Complexity Measure = 0.29232503668137355;
# q = 7.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6540459164206232; Complexity Measure = 0.2931932946044129;
# q = 7.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6517355785746598; Complexity Measure = 0.29403206638680424;
# q = 7.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6494634537873923; Complexity Measure = 0.2948423090546581;
# q = 8.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6472289499515292; Complexity Measure = 0.29562495218682244;
# q = 8.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.645031475974163; Complexity Measure = 0.2963808982729569;
# q = 8.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6428704423885012; Complexity Measure = 0.2971110231108941;
# q = 8.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6407452619137889; Complexity Measure = 0.29781617623794915;
# q = 8.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6386553499668962; Complexity Measure = 0.2984971813912905;
# q = 8.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6366001251288496; Complexity Measure = 0.29915483699291046;
# q = 8.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6345790095693927; Complexity Measure = 0.2997899166551441;
# q = 8.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6325914294324791; Complexity Measure = 0.30040316970305153;
# q = 8.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6306368151854291; Complexity Measure = 0.3009953217103033;
# q = 8.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6287146019343098; Complexity Measure = 0.30156707504555463;
# q = 9.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6268242297079464; Complexity Measure = 0.3021191094265614;
# q = 9.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6249651437128162; Complexity Measure = 0.30265208247957687;
# q = 9.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.623136794560938; Complexity Measure = 0.30316663030180874;
# q = 9.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.62133863847273; Complexity Measure = 0.3036633680249522;
# q = 9.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6195701374566882; Complexity Measure = 0.3041428903780161;
# q = 9.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6178307594676072; Complexity Measure = 0.304605772247871;
# q = 9.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6161199785449585; Complexity Measure = 0.30505256923609414;
# q = 9.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6144372749329283; Complexity Measure = 0.30548381821089904;
# q = 9.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6127821351835208; Complexity Measure = 0.3059000378530246;
# q = 9.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6111540522440317; Complexity Measure = 0.3063017291946531;
# q = 10.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6095525255301122; Complexity Measure = 0.30668937615051656;
# q = 10.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6079770609855526; Complexity Measure = 0.30706344604046515;
# q = 10.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6064271711298472; Complexity Measure = 0.30742439010290656;
# q = 10.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6049023750945135; Complexity Measure = 0.3077726439985674;
# q = 10.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6034021986490822; Complexity Measure = 0.30810862830417224;
# q = 10.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6019261742176024; Complexity Measure = 0.3084327489956571;
# q = 10.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6004738408864467; Complexity Measure = 0.30874539792065137;
# q = 10.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5990447444041481; Complexity Measure = 0.30904695325999126;
# q = 10.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5976384371739417; Complexity Measure = 0.3093377799781084;
# q = 10.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5962544782396406; Complexity Measure = 0.3096182302621732;
# q = 11.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5948924332654255; Complexity Measure = 0.3098886439499298;
# q = 11.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5935518745100863; Complexity Measure = 0.3101493489461884;
# q = 11.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5922323807962142; Complexity Measure = 0.3104006616279976;
# q = 11.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5909335374748053; Complexity Measure = 0.3106428872385233;
# q = 11.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5896549363857002; Complexity Measure = 0.3108763202697247;
# q = 11.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5883961758142592; Complexity Measure = 0.31110124483390794;
# q = 11.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5871568604446297; Complexity Measure = 0.31131793502429295;
# q = 11.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5859366013099502; Complexity Measure = 0.31152665526472134;
# q = 11.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5847350157397981; Complexity Measure = 0.3117276606486743;
# q = 11.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5835517273051679; Complexity Measure = 0.31192119726776485;
# q = 12.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5823863657612489; Complexity Measure = 0.3121075025298927;
# q = 12.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5812385669882415; Complexity Measure = 0.3122868054672561;
# q = 12.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5801079729304432; Complexity Measure = 0.31245932703443047;
# q = 12.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5789942315338084; Complexity Measure = 0.3126252803967203;
# q = 12.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5778969966821745; Complexity Measure = 0.3127848712090038;
# q = 12.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5768159281323338; Complexity Measure = 0.31293829788529653;
# q = 12.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5757506914481082; Complexity Measure = 0.3130857518592579;
# q = 12.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.574700957933583; Complexity Measure = 0.3132274178358659;
# q = 12.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5736664045656307; Complexity Measure = 0.3133634740344948;
# q = 12.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5726467139258585; Complexity Measure = 0.31349409242362997;
# q = 13.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5716415741320895; Complexity Measure = 0.3136194389474373;
# q = 13.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5706506787694885; Complexity Measure = 0.31373967374442674;
# q = 13.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5696737268214295; Complexity Measure = 0.31385495135844027;
# q = 13.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5687104226001946; Complexity Measure = 0.31396542094217994;
# q = 13.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5677604756775882; Complexity Measure = 0.3140712264535064;
# q = 13.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5668236008155395; Complexity Measure = 0.3141725068447306;
# q = 13.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.565899517896766; Complexity Measure = 0.31426939624510825;
# q = 13.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5649879518555592; Complexity Measure = 0.3143620241367569;
# q = 13.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5640886326087505; Complexity Measure = 0.31445051552420483;
# q = 13.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5632012949869114; Complexity Measure = 0.3145349910977752;
# q = 14.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5623256786658342; Complexity Measure = 0.3146155673910095;
# q = 14.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5614615280983389; Complexity Measure = 0.31469235693232733;
# q = 14.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5606085924464463; Complexity Measure = 0.31476546839111236;
# q = 14.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.55976662551395; Complexity Measure = 0.31483500671842;
# q = 14.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5589353856794244; Complexity Measure = 0.31490107328248146;
# q = 14.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5581146358296962; Complexity Measure = 0.3149637659991916;
# q = 14.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5573041432938054; Complexity Measure = 0.3150231794577463;
# q = 14.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5565036797774805; Complexity Measure = 0.31507940504160864;
# q = 14.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5557130212981485; Complexity Measure = 0.315132531044961;
# q = 14.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5549319481205012; Complexity Measure = 0.31518264278480485;
# q = 15.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.55416024469263; Complexity Measure = 0.3152298227088683;
# q = 15.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5533976995827491; Complexity Measure = 0.3152741504994669;
# q = 15.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.552644105416516; Complexity Measure = 0.31531570317346624;
# q = 15.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5518992588149642; Complexity Measure = 0.31535455517848754;
# q = 15.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5511629603330546; Complexity Measure = 0.31539077848549707;
# q = 15.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5504350143988564; Complexity Measure = 0.31542444267790715;
# q = 15.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5497152292533631; Complexity Measure = 0.3154556150373178;
# q = 15.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5490034168909497; Complexity Measure = 0.31548436062603313;
# q = 15.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5482993930004751; Complexity Measure = 0.3155107423664566;
# q = 15.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5476029769070363; Complexity Measure = 0.3155348211174986;
# q = 16.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5469139915143709; Complexity Measure = 0.3155566557480947;
# q = 16.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5462322632479167; Complexity Measure = 0.31557630320795493;
# q = 16.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5455576219985239; Complexity Measure = 0.3155938185956372;
# q = 16.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5448899010668222; Complexity Measure = 0.31560925522405897;
# q = 16.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5442289371082435; Complexity Measure = 0.31562266468353434;
# q = 16.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5435745700786965; Complexity Measure = 0.315634096902435;
# q = 16.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.542926643180893; Complexity Measure = 0.31564360020556903;
# q = 16.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5422850028113241; Complexity Measure = 0.3156512213703573;
# q = 16.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5416494985078828; Complexity Measure = 0.31565700568090044;
# q = 16.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5410199828981295; Complexity Measure = 0.31566099698001165;
# q = 17.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5403963116481995; Complexity Measure = 0.31566323771929844;
# q = 17.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5397783434123455; Complexity Measure = 0.31566376900736265;
# q = 17.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5391659397831134; Complexity Measure = 0.3156626306561996;
# q = 17.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5385589652421461; Complexity Measure = 0.31565986122585876;
# q = 17.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5379572871116111; Complexity Measure = 0.3156554980674388;
# q = 17.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5373607755062476; Complexity Measure = 0.3156495773644761;
# q = 17.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5367693032860273; Complexity Measure = 0.3156421341727995;
# q = 17.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5361827460094246; Complexity Measure = 0.31563320245889376;
# q = 17.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5356009818872919; Complexity Measure = 0.31562281513685353;
# q = 17.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5350238917373312; Complexity Measure = 0.31561100410395504;
# q = 18.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.534451358939164; Complexity Measure = 0.31559780027492745;
# q = 18.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5338832693899839; Complexity Measure = 0.31558323361495205;
# q = 18.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5333195114607968; Complexity Measure = 0.3155673331714526;
# q = 18.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5327599759532367; Complexity Measure = 0.31555012710471564;
# q = 18.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.532204556056953; Complexity Measure = 0.3155316427173959;
# q = 18.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5316531473075665; Complexity Measure = 0.3155119064829393;
# q = 18.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5311056475451843; Complexity Measure = 0.31549094407297357;
# q = 18.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5305619568734727; Complexity Measure = 0.31546878038370535;
# q = 18.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5300219776192794; Complexity Measure = 0.31544543956135973;
# q = 18.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5294856142928006; Complexity Measure = 0.31542094502670115;
# q = 19.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5289527735482901; Complexity Measure = 0.31539531949867583;
# q = 19.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5284233641452988; Complexity Measure = 0.3153685850171979;
# q = 19.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5278972969104492; Complexity Measure = 0.31534076296512803;
# q = 19.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5273744846997285; Complexity Measure = 0.3153118740894643;
# q = 19.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.526854842361305; Complexity Measure = 0.31528193852178144;
# q = 19.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5263382866988562; Complexity Measure = 0.31525097579794253;
# q = 19.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5258247364354071; Complexity Measure = 0.3152190048771195;
# q = 19.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5253141121776722; Complexity Measure = 0.31518604416014195;
# q = 19.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5248063363808965; Complexity Measure = 0.31515211150720057;
# q = 19.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5243013333141913; Complexity Measure = 0.31511722425493455;
# q = 20.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5237990290263607; Complexity Measure = 0.3150813992329243;

# %% [markdown]
# ## Generating both planes

# %%
image_title = 'Woody-D69'
freq_x = 20
freq_y = 50
amp = 50
data_ss = pd.read_csv(f"results/periodic_noise/{image_title}_{freq_x}_{freq_y}_{amp}.csv")

# %%
# SMOOTHNESS
plt.figure(1)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 14})
scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')

plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Smoothness')
plt.ylabel('Curve structure')
plt.title(f'SC {image_title} - Periodic fx {freq_x} fy {freq_y} a {amp}')

plt.savefig(f'results/periodic_noise/planes/{image_title}_SCplane_weighted.png', bbox_inches='tight')
        
# CECP
plt.figure(2)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 17})
scatter = plt.scatter(data_ss['Weighted Entropy Correct'], data_ss['Weighted Complexity Correct'], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Weighted Entropy')
plt.ylabel('Weighted Complexity')
plt.title(f'CECP {image_title} - Poisson fx {freq_x} fy {freq_y} a {amp}')

plt.savefig(f'results/periodic_noise/planes/{image_title}_CECPplane_weighted.png', bbox_inches='tight')
plt.clf() # clears the figure

# %% [markdown]
# ## Plotting the probabilities
