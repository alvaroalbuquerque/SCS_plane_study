# %% [markdown]
# # Poisson Noise Experiments

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
from utils.images_generator import poisson_noise, normalize_img_to_0_255, generate_histogram

# %%
images_class = 'Marble'
images_path = f'data/Normalized_Brodatz/{images_class}'
image_name = 'D58'
image_title = f'{images_class}-{image_name}'
gs_image = cv2.imread(f'{images_path}/{image_name}.tif', cv2.IMREAD_GRAYSCALE)
if gs_image is not None:
    plt.imshow(gs_image, cmap='gray')
    plt.title(f"Imagem {image_title}")
    plt.axis('off')  # Remove os eixos
    plt.show()
else:
    print('error')

# %%
plt.clf()
generate_histogram(gs_image, isNormalized=True, title=f'{image_title}')

# %%
poisson_image = poisson_noise(gs_image)

# Plot the results
plt.clf()
plt.figure(1,figsize=(12, 8))
plt.imshow(poisson_image, cmap='gray')
plt.title(f'{image_title} Poisson Noise')
plt.axis('off')  # Remove os eixos
plt.savefig(f'results/poisson_noise/{image_title}.png', bbox_inches='tight')

# %%
plt.clf()
generate_histogram(poisson_image, isNormalized=True, title=f'{image_title} Poisson Noise')
plt.savefig(f'results/poisson_noise/{image_title}_histogram.png', bbox_inches='tight')

# %% [markdown]
# ## Generating data for the images

# %%
from utils.experiments_functions import get_img_info

# %%
image_title = 'Marble-D58'
image_3_3_4_data = get_img_info(poisson_image, q_linspace = np.linspace(-2, 20, num = 221))
image_3_3_4_data.head(5)
image_3_3_4_data.to_csv(f"results/poisson_noise/{image_title}.csv", index = False)
# Out:
# q = -2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:624: RuntimeWarning: divide by zero encountered in power
#   weights                   = np.power(partitions.var(axis=1), q/2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:630: RuntimeWarning: invalid value encountered in divide
#   probabilities = total_variance_per_symbol/total_variance_per_symbol.sum()
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: divide by zero encountered in log
#   s_of_p_over_2 = -np.sum(probabilities*np.log(probabilities))/2
# C:\Users\Alvaro\Documents\1 - MESTRADO\Estudo dirigido\ordpy\ordpy\ordpy.py:739: RuntimeWarning: invalid value encountered in multiply
#   s_of_p_over_2 = -np.sum(probabilities*np.log(probabilities))/2
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.2999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.8999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.7999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.5999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.3999999999999999
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.2999999999999998
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.19999999999999996
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.09999999999999987
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = 0.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9693119832951956; Complexity Measure = 0.04061301678034747;
# q = 0.10000000000000009
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9675566089500622; Complexity Measure = 0.042937539743393566;
# q = 0.20000000000000018
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.965681095454577; Complexity Measure = 0.045406462585963286;
# q = 0.30000000000000027
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9637959002559937; Complexity Measure = 0.047885975706991706;
# q = 0.40000000000000036
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9618985399650926; Complexity Measure = 0.05037926106541083;
# q = 0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9599869016808469; Complexity Measure = 0.05288899959204614;
# q = 0.6000000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9580593378140869; Complexity Measure = 0.055417245781310555;
# q = 0.7000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9561147115285417; Complexity Measure = 0.05796536868488116;
# q = 0.8000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9541524064259803; Complexity Measure = 0.06053404097316269;
# q = 0.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9521723112065564; Complexity Measure = 0.06312326161358911;
# q = 1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9501747875536877; Complexity Measure = 0.06573240104576274;
# q = 1.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.948160627448254; Complexity Measure = 0.0683602604787385;
# q = 1.2000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9461310044836818; Complexity Measure = 0.07100513912977152;
# q = 1.3000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9440874224814669; Complexity Measure = 0.07366490493417797;
# q = 1.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9420316637372751; Complexity Measure = 0.0763370655613721;
# q = 1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9399657385028384; Complexity Measure = 0.07901883755070141;
# q = 1.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9378918367760019; Complexity Measure = 0.0817072121025505;
# q = 1.7000000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9358122830855243; Complexity Measure = 0.08439901658533218;
# q = 1.8000000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9337294946818503; Complexity Measure = 0.08709097119637706;
# q = 1.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9316459433509036; Complexity Measure = 0.0897797404830533;
# q = 2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9295641209324147; Complexity Measure = 0.09246197961968924;
# q = 2.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9274865085304945; Complexity Measure = 0.09513437546839705;
# q = 2.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9254155493395259; Complexity Measure = 0.09779368254435392;
# q = 2.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9233536249639971; Complexity Measure = 0.1004367540704288;
# q = 2.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9213030350802578; Complexity Measure = 0.10306056835068415;
# q = 2.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9192659802670107; Complexity Measure = 0.10566225072313548;
# q = 2.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9172445478167011; Complexity Measure = 0.10823909137312669;
# q = 2.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9152407003299807; Complexity Measure = 0.11078855930247114;
# q = 2.8000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9132562668888862; Complexity Measure = 0.1133083127577398;
# q = 2.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9112929366005947; Complexity Measure = 0.11579620642494223;
# q = 3.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9093522543021636; Complexity Measure = 0.11825029569796545;
# q = 3.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9074356182172951; Complexity Measure = 0.12066883832500162;
# q = 3.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.905544279358742; Complexity Measure = 0.12305029373121446;
# q = 3.3000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9036793424743299; Complexity Measure = 0.1253933203072219;
# q = 3.4000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9018417683406361; Complexity Measure = 0.12769677094210535;
# q = 3.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9000323772159676; Complexity Measure = 0.1299596870665846;
# q = 3.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8982518532732436; Complexity Measure = 0.13218129145732108;
# q = 3.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8965007498435579; Complexity Measure = 0.13436098003715943;
# q = 3.8000000000000007
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8947794953123103; Complexity Measure = 0.13649831288885791;
# q = 3.9000000000000004
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8930883995216745; Complexity Measure = 0.13859300468188693;
# q = 4.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8914276605455435; Complexity Measure = 0.14064491469342902;
# q = 4.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8897973717157628; Complexity Measure = 0.14265403658618506;
# q = 4.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8881975287911964; Complexity Measure = 0.14462048808717895;
# q = 4.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8866280371737633; Complexity Measure = 0.14654450069382396;
# q = 4.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8850887190878792; Complexity Measure = 0.1484264095161514;
# q = 4.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8835793206515539; Complexity Measure = 0.15026664334764625;
# q = 4.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8820995187786231; Complexity Measure = 0.15206571504159874;
# q = 4.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8806489278621277; Complexity Measure = 0.15382421225545326;
# q = 4.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8792271061986088; Complexity Measure = 0.15554278861238474;
# q = 4.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8778335621220255; Complexity Measure = 0.15722215531729677;
# q = 5.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8764677598240934; Complexity Measure = 0.15886307325356458;
# q = 5.1000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8751291248450646; Complexity Measure = 0.16046634557731843;
# q = 5.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8738170492253541; Complexity Measure = 0.16203281081757698;
# q = 5.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.872530896313976; Complexity Measure = 0.16356333648332005;
# q = 5.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8712700052345183; Complexity Measure = 0.16505881317237514;
# q = 5.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8700336950134104; Complexity Measure = 0.16652014917180122;
# q = 5.6000000000000005
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8688212683785747; Complexity Measure = 0.16794826553524364;
# q = 5.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8676320152392503; Complexity Measure = 0.16934409161927427;
# q = 5.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8664652158599035; Complexity Measure = 0.17070856105816343;
# q = 5.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8653201437427434; Complexity Measure = 0.17204260815452835;
# q = 6.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8641960682345092; Complexity Measure = 0.17334716466199154;
# q = 6.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8630922568739543; Complexity Measure = 0.17462315693514588;
# q = 6.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8620079774968368; Complexity Measure = 0.17587150342175734;
# q = 6.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8609425001153558; Complexity Measure = 0.1770931124721504;
# q = 6.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8598950985888171; Complexity Measure = 0.17828888044104324;
# q = 6.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8588650521019798; Complexity Measure = 0.1794596900577217;
# q = 6.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.857851646467026; Complexity Measure = 0.18060640904119452;
# q = 6.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8568541752644656; Complexity Measure = 0.18172988893799114;
# q = 6.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8558719408375534; Complexity Measure = 0.18283096416131717;
# q = 6.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8549042551539999; Complexity Measure = 0.18391045121146382;
# q = 7.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8539504405479124; Complexity Measure = 0.18496914805860223;
# q = 7.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8530098303540256; Complexity Measure = 0.18600783367035306;
# q = 7.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8520817694454146; Complexity Measure = 0.18702726766777766;
# q = 7.300000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.851165614684998; Complexity Measure = 0.18802819009470154;
# q = 7.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8502607353002901; Complexity Measure = 0.18901132128650613;
# q = 7.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8493665131900366; Complexity Measure = 0.18997736182571637;
# q = 7.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.848482343170564; Complexity Measure = 0.19092699257283893;
# q = 7.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8476076331689284; Complexity Measure = 0.19186087476203031;
# q = 7.800000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8467418043692326; Complexity Measure = 0.19277965015215265;
# q = 7.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.845884291317817; Complexity Measure = 0.19368394122479077;
# q = 8.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8450345419924086; Complexity Measure = 0.19457435142166818;
# q = 8.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8441920178397426; Complexity Measure = 0.19545146541475716;
# q = 8.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.843356193785651; Complexity Measure = 0.19631584940313584;
# q = 8.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8425265582211213; Complexity Measure = 0.19716805143138297;
# q = 8.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.841702612967413; Complexity Measure = 0.19800860172489443;
# q = 8.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.840883873222909; Complexity Measure = 0.19883801303817522;
# q = 8.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8400698674940417; Complexity Measure = 0.19965678101259296;
# q = 8.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8392601375123121; Complexity Measure = 0.2004653845406663;
# q = 8.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8384542381391461; Complexity Measure = 0.2012642861343036;
# q = 8.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8376517372600829; Complexity Measure = 0.20205393229483937;
# q = 9.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.83685221566958; Complexity Measure = 0.20283475388305527;
# q = 9.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8360552669475264; Complexity Measure = 0.20360716648764243;
# q = 9.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.835260497328397; Complexity Measure = 0.20437157079087395;
# q = 9.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8344675255638395; Complexity Measure = 0.2051283529304456;
# q = 9.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8336759827793648; Complexity Measure = 0.20587788485666456;
# q = 9.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8328855123257114; Complexity Measure = 0.20662052468435563;
# q = 9.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8320957696253705; Complexity Measure = 0.2073566170389625;
# q = 9.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8313064220146864; Complexity Measure = 0.20808649339649785;
# q = 9.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8305171485818843; Complexity Measure = 0.2088104724170703;
# q = 9.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.82972764000134; Complexity Measure = 0.20952886027181986;
# q = 10.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8289375983643543; Complexity Measure = 0.21024195096317766;
# q = 10.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8281467370066808; Complexity Measure = 0.2109500266384136;
# q = 10.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8273547803330146; Complexity Measure = 0.21165335789649492;
# q = 10.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8265614636386486; Complexity Measure = 0.2123522040883145;
# q = 10.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8257665329284782; Complexity Measure = 0.2130468136104023;
# q = 10.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8249697447335368; Complexity Measure = 0.21373742419220593;
# q = 10.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8241708659252274; Complexity Measure = 0.21442426317711077;
# q = 10.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8233696735274266; Complexity Measure = 0.21510754779733088;
# q = 10.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8225659545266201; Complexity Measure = 0.21578748544284176;
# q = 10.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8217595056802433; Complexity Measure = 0.21646427392450093;
# q = 11.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8209501333233907; Complexity Measure = 0.21713810173154893;
# q = 11.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8201376531740691; Complexity Measure = 0.21780914828362782;
# q = 11.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8193218901371603; Complexity Measure = 0.21847758417750004;
# q = 11.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8185026781072744; Complexity Measure = 0.21914357142861166;
# q = 11.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8176798597706657; Complexity Measure = 0.21980726370766182;
# q = 11.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8168532864063924; Complexity Measure = 0.2204688065723202;
# q = 11.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8160228176868985; Complexity Measure = 0.22112833769423518;
# q = 11.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8151883214782; Complexity Measure = 0.221785987081456;
# q = 11.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8143496736398569; Complexity Measure = 0.22244187729641088;
# q = 11.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8135067578249116; Complexity Measure = 0.22309612366954795;
# q = 12.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8126594652799783; Complexity Measure = 0.2237488345087445;
# q = 12.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8118076946456578; Complexity Measure = 0.2244001113046131;
# q = 12.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8109513517574596; Complexity Measure = 0.22505004893176714;
# q = 12.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8100903494474081; Complexity Measure = 0.22569873584617017;
# q = 12.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8092246073464998; Complexity Measure = 0.2263462542786386;
# q = 12.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8083540516881883; Complexity Measure = 0.22699268042457188;
# q = 12.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8074786151130565; Complexity Measure = 0.22763808463000346;
# q = 12.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8065982364748395; Complexity Measure = 0.22828253157402484;
# q = 12.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8057128606479537; Complexity Measure = 0.2289260804476596;
# q = 12.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8048224383366837; Complexity Measure = 0.22956878512924367;
# q = 13.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.803926925886171; Complexity Measure = 0.23021069435637007;
# q = 13.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.803026285095346; Complexity Measure = 0.2308518518944603;
# q = 13.200000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8021204830319334; Complexity Measure = 0.23149229670199817;
# q = 13.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8012094918496632; Complexity Measure = 0.23213206309249704;
# q = 13.4
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8002932886078035; Complexity Measure = 0.23277118089322113;
# q = 13.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7993718550931322; Complexity Measure = 0.2334096756007369;
# q = 13.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7984451776444548; Complexity Measure = 0.23404756853330214;
# q = 13.700000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7975132469797679; Complexity Measure = 0.23468487698016796;
# q = 13.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7965760580261648; Complexity Measure = 0.23532161434780552;
# q = 13.9
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7956336097525698; Complexity Measure = 0.23595779030311223;
# q = 14.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7946859050053807; Complexity Measure = 0.23659341091362998;
# q = 14.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7937329503470973; Complexity Measure = 0.2372284787848121;
# q = 14.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7927747558979992; Complexity Measure = 0.23786299319437387;
# q = 14.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7918113351809382; Complexity Measure = 0.2384969502237578;
# q = 14.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.790842704969296; Complexity Measure = 0.23913034288676027;
# q = 14.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7898688851381599; Complexity Measure = 0.2397631612553357;
# q = 14.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7888898985187556; Complexity Measure = 0.24039539258262674;
# q = 14.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7879057707561756; Complexity Measure = 0.24102702142324292;
# q = 14.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7869165301704317; Complexity Measure = 0.24165802975082906;
# q = 14.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7859222076208607; Complexity Measure = 0.24228839707294747;
# q = 15.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7849228363738955; Complexity Measure = 0.24291810054330995;
# q = 15.100000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7839184519742242; Complexity Measure = 0.24354711507139606;
# q = 15.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7829090921193406; Complexity Measure = 0.2441754134294787;
# q = 15.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7818947965374913; Complexity Measure = 0.244802966357102;
# q = 15.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7808756068690197; Complexity Measure = 0.24542974266303247;
# q = 15.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7798515665511018; Complexity Measure = 0.24605570932471496;
# q = 15.600000000000001
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7788227207058614; Complexity Measure = 0.2466808315852823;
# q = 15.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7777891160318573; Complexity Measure = 0.24730507304812357;
# q = 15.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7767508006989157; Complexity Measure = 0.2479283957690647;
# q = 15.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7757078242462948; Complexity Measure = 0.24855076034618193;
# q = 16.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7746602374841516; Complexity Measure = 0.24917212600728136;
# q = 16.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7736080923982848; Complexity Measure = 0.2497924506950845;
# q = 16.2
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7725514420581182; Complexity Measure = 0.2504116911501351;
# q = 16.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7714903405278979; Complexity Measure = 0.2510298029914759;
# q = 16.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7704248427810557; Complexity Measure = 0.2516467407951186;
# q = 16.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7693550046177063; Complexity Measure = 0.25226245817033977;
# q = 16.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7682808825852325; Complexity Measure = 0.2528769078338332;
# q = 16.7
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7672025339019127; Complexity Measure = 0.2534900416817599;
# q = 16.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.766120016383546; Complexity Measure = 0.2541018108597096;
# q = 16.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7650333883730236; Complexity Measure = 0.25471216583062656;
# q = 17.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7639427086727967; Complexity Measure = 0.2553210564407147;
# q = 17.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7628480364801885; Complexity Measure = 0.25592843198336857;
# q = 17.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7617494313254956; Complexity Measure = 0.25653424126114466;
# q = 17.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7606469530128231; Complexity Measure = 0.2571384326458268;
# q = 17.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7595406615635997; Complexity Measure = 0.25774095413659454;
# q = 17.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7584306171627094; Complexity Measure = 0.25834175341634674;
# q = 17.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7573168801071887; Complexity Measure = 0.258940777906198;
# q = 17.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7561995107574228; Complexity Measure = 0.259537974818189;
# q = 17.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7550785694907848; Complexity Measure = 0.2601332912062359;
# q = 17.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7539541166576574; Complexity Measure = 0.2607266740153567;
# q = 18.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7528262125397747; Complexity Measure = 0.2613180701291988;
# q = 18.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7516949173108207; Complexity Measure = 0.2619074264159092;
# q = 18.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7505602909992295; Complexity Measure = 0.2624946897723704;
# q = 18.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.749422393453118; Complexity Measure = 0.2630798071668382;
# q = 18.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.748281284307293; Complexity Measure = 0.26366272568000737;
# q = 18.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.747137022952273; Complexity Measure = 0.2642433925445469;
# q = 18.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7459896685052577; Complexity Measure = 0.2648217551831237;
# q = 18.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7448392797829898; Complexity Measure = 0.26539776124495573;
# q = 18.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7436859152764441; Complexity Measure = 0.2659713586409165;
# q = 18.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7425296331272853; Complexity Measure = 0.2665424955772296;
# q = 19.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.741370491106034; Complexity Measure = 0.26711112058778175;
# q = 19.1
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.740208546591882; Complexity Measure = 0.26767718256507855;
# q = 19.200000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7390438565540955; Complexity Measure = 0.26824063078987814;
# q = 19.3
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.737876477534953; Complexity Measure = 0.26880141495954124;
# q = 19.400000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7367064656341545; Complexity Measure = 0.2693594852151045;
# q = 19.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7355338764946493; Complexity Measure = 0.2699147921671298;
# q = 19.6
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7343587652898254; Complexity Measure = 0.27046728692034966;
# q = 19.700000000000003
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7331811867120044; Complexity Measure = 0.2710169210971286;
# q = 19.8
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7320011949621907; Complexity Measure = 0.2715636468597895;
# q = 19.900000000000002
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7308188437410165; Complexity Measure = 0.27210741693181173;
# q = 20.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7296341862408361; Complexity Measure = 0.2726481846179471;

# %% [markdown]
# ## Generating both planes

# %%
image_title = 'Marble-D58'
data_ss = pd.read_csv(f"results/poisson_noise/{image_title}.csv")

# %%
# SMOOTHNESS
plt.figure(1)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 14})
scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')

plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Smoothness')
plt.ylabel('Curve structure')
plt.title(f'SC {image_title} - Poisson Noise')

plt.savefig(f'results/poisson_noise/planes/{image_title}_SCplane_weighted.png', bbox_inches='tight')
        
# CECP
plt.figure(2)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 17})
scatter = plt.scatter(data_ss['Weighted Entropy Correct'], data_ss['Weighted Complexity Correct'], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Weighted Entropy')
plt.ylabel('Weighted Complexity')
plt.title(f'CECP {image_title} - Poisson Noise')

plt.savefig(f'results/poisson_noise/planes/{image_title}_CECPplane_weighted.png', bbox_inches='tight')
plt.clf() # clears the figure

# %% [markdown]
# ## Plotting the probabilities
