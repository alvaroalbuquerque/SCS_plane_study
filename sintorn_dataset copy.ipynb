# %% [markdown]
# # Sintorn Rotation Dataset Experiments

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# %%
from utils.images_generator import generate_histogram

# %%
images_path = f'data/Sintorn/hardware'
images_class = 'canesugar01'
rot = 'r000'
seg = 's001'

# %%
image_title = f'{images_class}-{rot}-{seg}'
print('Image title:',image_title)
gs_image = cv2.imread(f'{images_path}/{image_title}.png', cv2.IMREAD_GRAYSCALE)
if gs_image is not None:
    plt.imshow(gs_image, cmap='gray')
    plt.title(f"Imagem {image_title}")
    plt.axis('off')  # Remove os eixos
    plt.show()
else:
    print('error')
# Out:
# Image title: canesugar01-r000-s001

# %%
generate_histogram(gs_image, isNormalized=True, title=f'{image_title}')
plt.savefig(f'results/sintorn_dataset/{image_title}_histogram.png')

# %% [markdown]
# ## Generating data for the images

# %%
from utils.experiments_functions import get_img_info

# %%
image_title = 'canesugar01-r000-s001'
image_data = get_img_info(gs_image, q_linspace = np.linspace(-2, 20, num = 45))
image_data.head(5)
image_data.to_csv(f"results/sintorn_dataset/{image_title}.csv", index = False)
# Out:
# q = -2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = -0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = -0.0; Complexity Measure = nan;
# q = 0.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9323214799375507; Complexity Measure = 0.0845233567479737;
# q = 0.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9220879468650324; Complexity Measure = 0.09883660861228913;
# q = 1.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.9048980736461664; Complexity Measure = 0.12039738961153591;
# q = 1.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8860685305887338; Complexity Measure = 0.14324424102761013;
# q = 2.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8680043601052055; Complexity Measure = 0.1643740506995232;
# q = 2.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8519591912586413; Complexity Measure = 0.18235823459706882;
# q = 3.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8382179007852005; Complexity Measure = 0.19700142176625124;
# q = 3.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8265165437782; Complexity Measure = 0.20874698579485423;
# q = 4.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.8163846812631322; Complexity Measure = 0.21823485675961415;
# q = 4.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.807332972029029; Complexity Measure = 0.2260789941227283;
# q = 5.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7989281979803736; Complexity Measure = 0.23278986925698572;
# q = 5.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.790811474794432; Complexity Measure = 0.2387640364077044;
# q = 6.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.78269473535512; Complexity Measure = 0.24429583473338842;
# q = 6.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.774351546058468; Complexity Measure = 0.2495924069972261;
# q = 7.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7656078806197087; Complexity Measure = 0.25478674753301017;
# q = 7.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7563341204846932; Complexity Measure = 0.25994875849409;
# q = 8.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7464381680217436; Complexity Measure = 0.26509552370449724;
# q = 8.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7358593416028707; Complexity Measure = 0.270201654803597;
# q = 9.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7245628627889955; Complexity Measure = 0.27520984563871864;
# q = 9.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.7125349239297508; Complexity Measure = 0.2800412336446655;
# q = 10.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6997784237243972; Complexity Measure = 0.28460496973117627;
# q = 10.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6863094599265738; Complexity Measure = 0.2888064816499783;
# q = 11.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6721546033230906; Complexity Measure = 0.29255413851578665;
# q = 11.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.657348891341501; Complexity Measure = 0.2957642588459394;
# q = 12.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6419344098074865; Complexity Measure = 0.2983645794728094;
# q = 12.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6259592951521006; Complexity Measure = 0.30029639944297115;
# q = 13.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.6094769875974664; Complexity Measure = 0.3015156447076826;
# q = 13.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5925455897143229; Complexity Measure = 0.30199308978688266;
# q = 14.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5752272225945478; Complexity Measure = 0.3017139431826696;
# q = 14.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5575873134537663; Complexity Measure = 0.3006769686562687;
# q = 15.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5396937865939538; Complexity Measure = 0.2988932822041131;
# q = 15.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5216161602923138; Complexity Measure = 0.29638493745303085;
# q = 16.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.5034245738239056; Complexity Measure = 0.2931833903306615;
# q = 16.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.4851887816471159; Complexity Measure = 0.28932791624832827;
# q = 17.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.46697715694624087; Complexity Measure = 0.28486403848045255;
# q = 17.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.44885574586359506; Complexity Measure = 0.2798420139969846;
# q = 18.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.4308874086099681; Complexity Measure = 0.2743154121034068;
# q = 18.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.41313107585919556; Complexity Measure = 0.2683398115596834;
# q = 19.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.39564113982416277; Complexity Measure = 0.26197163327377254;
# q = 19.5
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.3784669903031719; Complexity Measure = 0.25526711818776365;
# q = 20.0
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# dx = 2
# dy = 2
# tauy = 1
# taux = 1
# window_shape = (2, 2)
# Result: Entropy = 0.36165269759893853; Complexity Measure = 0.24828145361740822;

# %% [markdown]
# ## Generating both planes

# %%
image_title = 'canesugar01-r000-s001'
image_data = pd.read_csv(f"results/sintorn_dataset/{image_title}.csv")

# %%
data_ss=image_data
# SMOOTHNESS
plt.figure(1)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 14})
scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')

plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Smoothness')
plt.ylabel('Curve structure')
plt.title(f'SC {image_title}')

plt.savefig(f'results/sintorn_dataset/planes/{image_title}_SCplane_weighted.png')
        
# CECP
plt.figure(2)
plt.clf() # clears the figure
plt.rcParams.update({"font.size": 17})
scatter = plt.scatter(data_ss['Weighted Entropy Correct'], data_ss['Weighted Complexity Correct'], c=data_ss['q'], cmap='gist_rainbow')
# Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
special_symbols = {0: 'o', 1: 's', 2: '^'}
for q_value, marker in special_symbols.items():
    subset = data_ss[data_ss['q'] == q_value]
    plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
plt.colorbar(scatter, label='Parameter q')
# plt.ylim([0, 1])
# plt.xlim([0, 1])
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Weighted Entropy')
plt.ylabel('Weighted Complexity')
plt.title(f'CECP {image_title}')

plt.savefig(f'results/sintorn_dataset/planes/{image_title}_CECPplane_weighted.png')
plt.clf() # clears the figure

# %% [markdown]
# # Experiment multiple images

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# %%
images_path = f'data/Sintorn/hardware'
images_class = 'canvas01'
rot = 'r000'
seg = 's001'
images_filenames = []
for file in os.listdir(images_path):
    if file.startswith(images_class):
        images_filenames.append(file)

# %%
images_filenames_sample = np.random.choice(images_filenames, 20)
print(images_filenames_sample)
# Out:
# ['canvas01-r040-s053.png' 'canvas01-r280-s028.png'
#  'canvas01-r280-s087.png' 'canvas01-r160-s095.png'
#  'canvas01-r040-s009.png' 'canvas01-r040-s086.png'
#  'canvas01-r320-s017.png' 'canvas01-r280-s055.png'
#  'canvas01-r280-s081.png' 'canvas01-r040-s090.png'
#  'canvas01-r080-s004.png' 'canvas01-r040-s061.png'
#  'canvas01-r000-s053.png' 'canvas01-r160-s011.png'
#  'canvas01-r320-s039.png' 'canvas01-r240-s028.png'
#  'canvas01-r040-s095.png' 'canvas01-r120-s018.png'
#  'canvas01-r040-s099.png' 'canvas01-r040-s081.png']

# %%
'''
num = 45
num = 23
'''
from utils.experiments_functions import get_img_info
image_data_list = []
for idx, img_filename in enumerate(images_filenames):
    gs_image = cv2.imread(f'{images_path}/{img_filename}', cv2.IMREAD_GRAYSCALE)
    image_title = img_filename.split('.')[0]
    print(image_title, f"{idx}/{len(images_filenames)}")
    image_data = get_img_info(gs_image, q_linspace = np.linspace(-2, 20, num = 23))
    image_data['filename'] = img_filename
    image_data_list.append(image_data)

# %%
data_ss = pd.concat(image_data_list, ignore_index=True)
data_ss.to_csv(f"results/sintorn_dataset/{images_class}.csv", index = False)

# %%
plt.figure(1)
plt.clf() # clears the figure
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Smoothness')
plt.ylabel('Curve structure')
plt.title(f'SC {image_title}')
plt.figure(2)
plt.clf() # clears the figure
plt.ylim([-1, 1])
plt.xlim([-1, 1])
plt.grid()
plt.xlabel('Weighted Entropy')
plt.ylabel('Weighted Complexity')
plt.title(f'CECP {image_title}')
for data_ss in image_data_list:
    # SMOOTHNESS
    plt.figure(1)
    plt.rcParams.update({"font.size": 14})
    scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
    # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
    special_symbols = {0: 'o', 1: 's', 2: '^'}
    for q_value, marker in special_symbols.items():
        subset = data_ss[data_ss['q'] == q_value]
        plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')

    # plt.colorbar(scatter, label='Parameter q')
    # plt.ylim([0, 1])
    # plt.xlim([0, 1])

    # plt.savefig(f'results/sintorn_dataset/planes/{image_title}_SCplane_weighted.png')
            
    # CECP
    plt.figure(2)
    plt.rcParams.update({"font.size": 17})
    scatter = plt.scatter(data_ss['Weighted Entropy Correct'], data_ss['Weighted Complexity Correct'], c=data_ss['q'], cmap='gist_rainbow')
    # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
    special_symbols = {0: 'o', 1: 's', 2: '^'}
    for q_value, marker in special_symbols.items():
        subset = data_ss[data_ss['q'] == q_value]
        plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
    # plt.colorbar(scatter, label='Parameter q')
    # plt.ylim([0, 1])
    # plt.xlim([0, 1])

    # plt.savefig(f'results/sintorn_dataset/planes/{image_title}_CECPplane_weighted.png')
# plt.figure(1)
# plt.colorbar(scatter, label='Parameter q')
# plt.figure(2)
plt.colorbar(scatter, label='Parameter q')

# %% [markdown]
# Multiple images dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# %%
images_path = f'data/Sintorn/hardware'
images_class = 'canvas01'
data_ss_all = pd.read_csv(f"results/sintorn_dataset/{images_class}.csv")
print(data_ss_all.head())
# Out:
#      q  Smoothness  Curve structure  Weighted Entropy Correct  \
# 0 -2.0         NaN         0.000000                 -0.000000
# 1 -1.0         NaN         0.000000                 -0.000000
# 2  0.0    0.147098         0.192132                  0.960962
# 3  1.0    0.189736         0.233035                  0.937726
# 4  2.0    0.228652         0.261921                  0.910571
#
#    Weighted Complexity Correct     prob0     prob1     prob2  \
# 0                          NaN       NaN  0.000000  0.000000
# 1                          NaN       NaN  0.000000  0.000000
# 2                     0.049154  0.480432  0.355850  0.163718
# 3                     0.076621  0.523069  0.354983  0.121948
# 4                     0.107376  0.561985  0.349968  0.088047
#
#                  filename
# 0  canvas01-r000-s001.png
# 1  canvas01-r000-s001.png
# 2  canvas01-r000-s001.png
# 3  canvas01-r000-s001.png
# 4  canvas01-r000-s001.png

# %%
filenames = data_ss_all.filename.unique()
print(filenames)
# Out:
# ['canvas01-r000-s001.png' 'canvas01-r000-s002.png'
#  'canvas01-r000-s003.png' 'canvas01-r000-s004.png'
#  'canvas01-r000-s005.png' 'canvas01-r000-s006.png'
#  'canvas01-r000-s007.png' 'canvas01-r000-s008.png'
#  'canvas01-r000-s009.png' 'canvas01-r000-s010.png'
#  'canvas01-r000-s011.png' 'canvas01-r000-s012.png'
#  'canvas01-r000-s013.png' 'canvas01-r000-s014.png'
#  'canvas01-r000-s015.png' 'canvas01-r000-s016.png'
#  'canvas01-r000-s017.png' 'canvas01-r000-s018.png'
#  'canvas01-r000-s019.png' 'canvas01-r000-s020.png'
#  'canvas01-r000-s021.png' 'canvas01-r000-s022.png'
#  'canvas01-r000-s023.png' 'canvas01-r000-s024.png'
#  'canvas01-r000-s025.png' 'canvas01-r000-s026.png'
#  'canvas01-r000-s027.png' 'canvas01-r000-s028.png'
#  'canvas01-r000-s029.png' 'canvas01-r000-s030.png'
#  'canvas01-r000-s031.png' 'canvas01-r000-s032.png'
#  'canvas01-r000-s033.png' 'canvas01-r000-s034.png'
#  'canvas01-r000-s035.png' 'canvas01-r000-s036.png'
#  'canvas01-r000-s037.png' 'canvas01-r000-s038.png'
#  'canvas01-r000-s039.png' 'canvas01-r000-s040.png'
#  'canvas01-r000-s041.png' 'canvas01-r000-s042.png'
#  'canvas01-r000-s043.png' 'canvas01-r000-s044.png'
#  'canvas01-r000-s045.png' 'canvas01-r000-s046.png'
#  'canvas01-r000-s047.png' 'canvas01-r000-s048.png'
#  'canvas01-r000-s049.png' 'canvas01-r000-s050.png'
#  'canvas01-r000-s051.png' 'canvas01-r000-s052.png'
#  'canvas01-r000-s053.png' 'canvas01-r000-s054.png'
#  'canvas01-r000-s055.png' 'canvas01-r000-s056.png'
#  'canvas01-r000-s057.png' 'canvas01-r000-s058.png'
#  'canvas01-r000-s059.png' 'canvas01-r000-s060.png'
#  'canvas01-r000-s061.png' 'canvas01-r000-s062.png'
#  'canvas01-r000-s063.png' 'canvas01-r000-s064.png'
#  'canvas01-r000-s065.png' 'canvas01-r000-s066.png'
#  'canvas01-r000-s067.png' 'canvas01-r000-s068.png'
#  'canvas01-r000-s069.png' 'canvas01-r000-s070.png'
#  'canvas01-r000-s071.png' 'canvas01-r000-s072.png'
#  'canvas01-r000-s073.png' 'canvas01-r000-s074.png'
#  'canvas01-r000-s075.png' 'canvas01-r000-s076.png'
#  'canvas01-r000-s077.png' 'canvas01-r000-s078.png'
#  'canvas01-r000-s079.png' 'canvas01-r000-s080.png'
#  'canvas01-r000-s081.png' 'canvas01-r000-s082.png'
#  'canvas01-r000-s083.png' 'canvas01-r000-s084.png'
#  'canvas01-r000-s085.png' 'canvas01-r000-s086.png'
#  'canvas01-r000-s087.png' 'canvas01-r000-s088.png'
#  'canvas01-r000-s089.png' 'canvas01-r000-s090.png'
#  'canvas01-r000-s091.png' 'canvas01-r000-s092.png'
#  'canvas01-r000-s093.png' 'canvas01-r000-s094.png'
#  'canvas01-r000-s095.png' 'canvas01-r000-s096.png'
#  'canvas01-r000-s097.png' 'canvas01-r000-s098.png'
#  'canvas01-r000-s099.png' 'canvas01-r000-s100.png'
#  'canvas01-r040-s001.png' 'canvas01-r040-s002.png'
#  'canvas01-r040-s003.png' 'canvas01-r040-s004.png'
#  'canvas01-r040-s005.png' 'canvas01-r040-s006.png'
#  'canvas01-r040-s007.png' 'canvas01-r040-s008.png'
#  'canvas01-r040-s009.png' 'canvas01-r040-s010.png'
#  'canvas01-r040-s011.png' 'canvas01-r040-s012.png'
#  'canvas01-r040-s013.png' 'canvas01-r040-s014.png'
#  'canvas01-r040-s015.png' 'canvas01-r040-s016.png'
#  'canvas01-r040-s017.png' 'canvas01-r040-s018.png'
#  'canvas01-r040-s019.png' 'canvas01-r040-s020.png'
#  'canvas01-r040-s021.png' 'canvas01-r040-s022.png'
#  'canvas01-r040-s023.png' 'canvas01-r040-s024.png'
#  'canvas01-r040-s025.png' 'canvas01-r040-s026.png'
#  'canvas01-r040-s027.png' 'canvas01-r040-s028.png'
#  'canvas01-r040-s029.png' 'canvas01-r040-s030.png'
#  'canvas01-r040-s031.png' 'canvas01-r040-s032.png'
#  'canvas01-r040-s033.png' 'canvas01-r040-s034.png'
#  'canvas01-r040-s035.png' 'canvas01-r040-s036.png'
#  'canvas01-r040-s037.png' 'canvas01-r040-s038.png'
#  'canvas01-r040-s039.png' 'canvas01-r040-s040.png'
#  'canvas01-r040-s041.png' 'canvas01-r040-s042.png'
#  'canvas01-r040-s043.png' 'canvas01-r040-s044.png'
#  'canvas01-r040-s045.png' 'canvas01-r040-s046.png'
#  'canvas01-r040-s047.png' 'canvas01-r040-s048.png'
#  'canvas01-r040-s049.png' 'canvas01-r040-s050.png'
#  'canvas01-r040-s051.png' 'canvas01-r040-s052.png'
#  'canvas01-r040-s053.png' 'canvas01-r040-s054.png'
#  'canvas01-r040-s055.png' 'canvas01-r040-s056.png'
#  'canvas01-r040-s057.png' 'canvas01-r040-s058.png'
#  'canvas01-r040-s059.png' 'canvas01-r040-s060.png'
#  'canvas01-r040-s061.png' 'canvas01-r040-s062.png'
#  'canvas01-r040-s063.png' 'canvas01-r040-s064.png'
#  'canvas01-r040-s065.png' 'canvas01-r040-s066.png'
#  'canvas01-r040-s067.png' 'canvas01-r040-s068.png'
#  'canvas01-r040-s069.png' 'canvas01-r040-s070.png'
#  'canvas01-r040-s071.png' 'canvas01-r040-s072.png'
#  'canvas01-r040-s073.png' 'canvas01-r040-s074.png'
#  'canvas01-r040-s075.png' 'canvas01-r040-s076.png'
#  'canvas01-r040-s077.png' 'canvas01-r040-s078.png'
#  'canvas01-r040-s079.png' 'canvas01-r040-s080.png'
#  'canvas01-r040-s081.png' 'canvas01-r040-s082.png'
#  'canvas01-r040-s083.png' 'canvas01-r040-s084.png'
#  'canvas01-r040-s085.png' 'canvas01-r040-s086.png'
#  'canvas01-r040-s087.png' 'canvas01-r040-s088.png'
#  'canvas01-r040-s089.png' 'canvas01-r040-s090.png'
#  'canvas01-r040-s091.png' 'canvas01-r040-s092.png'
#  'canvas01-r040-s093.png' 'canvas01-r040-s094.png'
#  'canvas01-r040-s095.png' 'canvas01-r040-s096.png'
#  'canvas01-r040-s097.png' 'canvas01-r040-s098.png'
#  'canvas01-r040-s099.png' 'canvas01-r040-s100.png'
#  'canvas01-r080-s001.png' 'canvas01-r080-s002.png'
#  'canvas01-r080-s003.png' 'canvas01-r080-s004.png'
#  'canvas01-r080-s005.png' 'canvas01-r080-s006.png'
#  'canvas01-r080-s007.png' 'canvas01-r080-s008.png'
#  'canvas01-r080-s009.png' 'canvas01-r080-s010.png'
#  'canvas01-r080-s011.png' 'canvas01-r080-s012.png'
#  'canvas01-r080-s013.png' 'canvas01-r080-s014.png'
#  'canvas01-r080-s015.png' 'canvas01-r080-s016.png'
#  'canvas01-r080-s017.png' 'canvas01-r080-s018.png'
#  'canvas01-r080-s019.png' 'canvas01-r080-s020.png'
#  'canvas01-r080-s021.png' 'canvas01-r080-s022.png'
#  'canvas01-r080-s023.png' 'canvas01-r080-s024.png'
#  'canvas01-r080-s025.png' 'canvas01-r080-s026.png'
#  'canvas01-r080-s027.png' 'canvas01-r080-s028.png'
#  'canvas01-r080-s029.png' 'canvas01-r080-s030.png'
#  'canvas01-r080-s031.png' 'canvas01-r080-s032.png'
#  'canvas01-r080-s033.png' 'canvas01-r080-s034.png'
#  'canvas01-r080-s035.png' 'canvas01-r080-s036.png'
#  'canvas01-r080-s037.png' 'canvas01-r080-s038.png'
#  'canvas01-r080-s039.png' 'canvas01-r080-s040.png'
#  'canvas01-r080-s041.png' 'canvas01-r080-s042.png'
#  'canvas01-r080-s043.png' 'canvas01-r080-s044.png'
#  'canvas01-r080-s045.png' 'canvas01-r080-s046.png'
#  'canvas01-r080-s047.png' 'canvas01-r080-s048.png'
#  'canvas01-r080-s049.png' 'canvas01-r080-s050.png'
#  'canvas01-r080-s051.png' 'canvas01-r080-s052.png'
#  'canvas01-r080-s053.png' 'canvas01-r080-s054.png'
#  'canvas01-r080-s055.png' 'canvas01-r080-s056.png'
#  'canvas01-r080-s057.png' 'canvas01-r080-s058.png'
#  'canvas01-r080-s059.png' 'canvas01-r080-s060.png'
#  'canvas01-r080-s061.png' 'canvas01-r080-s062.png'
#  'canvas01-r080-s063.png' 'canvas01-r080-s064.png'
#  'canvas01-r080-s065.png' 'canvas01-r080-s066.png'
#  'canvas01-r080-s067.png' 'canvas01-r080-s068.png'
#  'canvas01-r080-s069.png' 'canvas01-r080-s070.png'
#  'canvas01-r080-s071.png' 'canvas01-r080-s072.png'
#  'canvas01-r080-s073.png' 'canvas01-r080-s074.png'
#  'canvas01-r080-s075.png' 'canvas01-r080-s076.png'
#  'canvas01-r080-s077.png' 'canvas01-r080-s078.png'
#  'canvas01-r080-s079.png' 'canvas01-r080-s080.png'
#  'canvas01-r080-s081.png' 'canvas01-r080-s082.png'
#  'canvas01-r080-s083.png' 'canvas01-r080-s084.png'
#  'canvas01-r080-s085.png' 'canvas01-r080-s086.png'
#  'canvas01-r080-s087.png' 'canvas01-r080-s088.png'
#  'canvas01-r080-s089.png' 'canvas01-r080-s090.png'
#  'canvas01-r080-s091.png' 'canvas01-r080-s092.png'
#  'canvas01-r080-s093.png' 'canvas01-r080-s094.png'
#  'canvas01-r080-s095.png' 'canvas01-r080-s096.png'
#  'canvas01-r080-s097.png' 'canvas01-r080-s098.png'
#  'canvas01-r080-s099.png' 'canvas01-r080-s100.png'
#  'canvas01-r120-s001.png' 'canvas01-r120-s002.png'
#  'canvas01-r120-s003.png' 'canvas01-r120-s004.png'
#  'canvas01-r120-s005.png' 'canvas01-r120-s006.png'
#  'canvas01-r120-s007.png' 'canvas01-r120-s008.png'
#  'canvas01-r120-s009.png' 'canvas01-r120-s010.png'
#  'canvas01-r120-s011.png' 'canvas01-r120-s012.png'
#  'canvas01-r120-s013.png' 'canvas01-r120-s014.png'
#  'canvas01-r120-s015.png' 'canvas01-r120-s016.png'
#  'canvas01-r120-s017.png' 'canvas01-r120-s018.png'
#  'canvas01-r120-s019.png' 'canvas01-r120-s020.png'
#  'canvas01-r120-s021.png' 'canvas01-r120-s022.png'
#  'canvas01-r120-s023.png' 'canvas01-r120-s024.png'
#  'canvas01-r120-s025.png' 'canvas01-r120-s026.png'
#  'canvas01-r120-s027.png' 'canvas01-r120-s028.png'
#  'canvas01-r120-s029.png' 'canvas01-r120-s030.png'
#  'canvas01-r120-s031.png' 'canvas01-r120-s032.png'
#  'canvas01-r120-s033.png' 'canvas01-r120-s034.png'
#  'canvas01-r120-s035.png' 'canvas01-r120-s036.png'
#  'canvas01-r120-s037.png' 'canvas01-r120-s038.png'
#  'canvas01-r120-s039.png' 'canvas01-r120-s040.png'
#  'canvas01-r120-s041.png' 'canvas01-r120-s042.png'
#  'canvas01-r120-s043.png' 'canvas01-r120-s044.png'
#  'canvas01-r120-s045.png' 'canvas01-r120-s046.png'
#  'canvas01-r120-s047.png' 'canvas01-r120-s048.png'
#  'canvas01-r120-s049.png' 'canvas01-r120-s050.png'
#  'canvas01-r120-s051.png' 'canvas01-r120-s052.png'
#  'canvas01-r120-s053.png' 'canvas01-r120-s054.png'
#  'canvas01-r120-s055.png' 'canvas01-r120-s056.png'
#  'canvas01-r120-s057.png' 'canvas01-r120-s058.png'
#  'canvas01-r120-s059.png' 'canvas01-r120-s060.png'
#  'canvas01-r120-s061.png' 'canvas01-r120-s062.png'
#  'canvas01-r120-s063.png' 'canvas01-r120-s064.png'
#  'canvas01-r120-s065.png' 'canvas01-r120-s066.png'
#  'canvas01-r120-s067.png' 'canvas01-r120-s068.png'
#  'canvas01-r120-s069.png' 'canvas01-r120-s070.png'
#  'canvas01-r120-s071.png' 'canvas01-r120-s072.png'
#  'canvas01-r120-s073.png' 'canvas01-r120-s074.png'
#  'canvas01-r120-s075.png' 'canvas01-r120-s076.png'
#  'canvas01-r120-s077.png' 'canvas01-r120-s078.png'
#  'canvas01-r120-s079.png' 'canvas01-r120-s080.png'
#  'canvas01-r120-s081.png' 'canvas01-r120-s082.png'
#  'canvas01-r120-s083.png' 'canvas01-r120-s084.png'
#  'canvas01-r120-s085.png' 'canvas01-r120-s086.png'
#  'canvas01-r120-s087.png' 'canvas01-r120-s088.png'
#  'canvas01-r120-s089.png' 'canvas01-r120-s090.png'
#  'canvas01-r120-s091.png' 'canvas01-r120-s092.png'
#  'canvas01-r120-s093.png' 'canvas01-r120-s094.png'
#  'canvas01-r120-s095.png' 'canvas01-r120-s096.png'
#  'canvas01-r120-s097.png' 'canvas01-r120-s098.png'
#  'canvas01-r120-s099.png' 'canvas01-r120-s100.png'
#  'canvas01-r160-s001.png' 'canvas01-r160-s002.png'
#  'canvas01-r160-s003.png' 'canvas01-r160-s004.png'
#  'canvas01-r160-s005.png' 'canvas01-r160-s006.png'
#  'canvas01-r160-s007.png' 'canvas01-r160-s008.png'
#  'canvas01-r160-s009.png' 'canvas01-r160-s010.png'
#  'canvas01-r160-s011.png' 'canvas01-r160-s012.png'
#  'canvas01-r160-s013.png' 'canvas01-r160-s014.png'
#  'canvas01-r160-s015.png' 'canvas01-r160-s016.png'
#  'canvas01-r160-s017.png' 'canvas01-r160-s018.png'
#  'canvas01-r160-s019.png' 'canvas01-r160-s020.png'
#  'canvas01-r160-s021.png' 'canvas01-r160-s022.png'
#  'canvas01-r160-s023.png' 'canvas01-r160-s024.png'
#  'canvas01-r160-s025.png' 'canvas01-r160-s026.png'
#  'canvas01-r160-s027.png' 'canvas01-r160-s028.png'
#  'canvas01-r160-s029.png' 'canvas01-r160-s030.png'
#  'canvas01-r160-s031.png' 'canvas01-r160-s032.png'
#  'canvas01-r160-s033.png' 'canvas01-r160-s034.png'
#  'canvas01-r160-s035.png' 'canvas01-r160-s036.png'
#  'canvas01-r160-s037.png' 'canvas01-r160-s038.png'
#  'canvas01-r160-s039.png' 'canvas01-r160-s040.png'
#  'canvas01-r160-s041.png' 'canvas01-r160-s042.png'
#  'canvas01-r160-s043.png' 'canvas01-r160-s044.png'
#  'canvas01-r160-s045.png' 'canvas01-r160-s046.png'
#  'canvas01-r160-s047.png' 'canvas01-r160-s048.png'
#  'canvas01-r160-s049.png' 'canvas01-r160-s050.png'
#  'canvas01-r160-s051.png' 'canvas01-r160-s052.png'
#  'canvas01-r160-s053.png' 'canvas01-r160-s054.png'
#  'canvas01-r160-s055.png' 'canvas01-r160-s056.png'
#  'canvas01-r160-s057.png' 'canvas01-r160-s058.png'
#  'canvas01-r160-s059.png' 'canvas01-r160-s060.png'
#  'canvas01-r160-s061.png' 'canvas01-r160-s062.png'
#  'canvas01-r160-s063.png' 'canvas01-r160-s064.png'
#  'canvas01-r160-s065.png' 'canvas01-r160-s066.png'
#  'canvas01-r160-s067.png' 'canvas01-r160-s068.png'
#  'canvas01-r160-s069.png' 'canvas01-r160-s070.png'
#  'canvas01-r160-s071.png' 'canvas01-r160-s072.png'
#  'canvas01-r160-s073.png' 'canvas01-r160-s074.png'
#  'canvas01-r160-s075.png' 'canvas01-r160-s076.png'
#  'canvas01-r160-s077.png' 'canvas01-r160-s078.png'
#  'canvas01-r160-s079.png' 'canvas01-r160-s080.png'
#  'canvas01-r160-s081.png' 'canvas01-r160-s082.png'
#  'canvas01-r160-s083.png' 'canvas01-r160-s084.png'
#  'canvas01-r160-s085.png' 'canvas01-r160-s086.png'
#  'canvas01-r160-s087.png' 'canvas01-r160-s088.png'
#  'canvas01-r160-s089.png' 'canvas01-r160-s090.png'
#  'canvas01-r160-s091.png' 'canvas01-r160-s092.png'
#  'canvas01-r160-s093.png' 'canvas01-r160-s094.png'
#  'canvas01-r160-s095.png' 'canvas01-r160-s096.png'
#  'canvas01-r160-s097.png' 'canvas01-r160-s098.png'
#  'canvas01-r160-s099.png' 'canvas01-r160-s100.png'
#  'canvas01-r200-s001.png' 'canvas01-r200-s002.png'
#  'canvas01-r200-s003.png' 'canvas01-r200-s004.png'
#  'canvas01-r200-s005.png' 'canvas01-r200-s006.png'
#  'canvas01-r200-s007.png' 'canvas01-r200-s008.png'
#  'canvas01-r200-s009.png' 'canvas01-r200-s010.png'
#  'canvas01-r200-s011.png' 'canvas01-r200-s012.png'
#  'canvas01-r200-s013.png' 'canvas01-r200-s014.png'
#  'canvas01-r200-s015.png' 'canvas01-r200-s016.png'
#  'canvas01-r200-s017.png' 'canvas01-r200-s018.png'
#  'canvas01-r200-s019.png' 'canvas01-r200-s020.png'
#  'canvas01-r200-s021.png' 'canvas01-r200-s022.png'
#  'canvas01-r200-s023.png' 'canvas01-r200-s024.png'
#  'canvas01-r200-s025.png' 'canvas01-r200-s026.png'
#  'canvas01-r200-s027.png' 'canvas01-r200-s028.png'
#  'canvas01-r200-s029.png' 'canvas01-r200-s030.png'
#  'canvas01-r200-s031.png' 'canvas01-r200-s032.png'
#  'canvas01-r200-s033.png' 'canvas01-r200-s034.png'
#  'canvas01-r200-s035.png' 'canvas01-r200-s036.png'
#  'canvas01-r200-s037.png' 'canvas01-r200-s038.png'
#  'canvas01-r200-s039.png' 'canvas01-r200-s040.png'
#  'canvas01-r200-s041.png' 'canvas01-r200-s042.png'
#  'canvas01-r200-s043.png' 'canvas01-r200-s044.png'
#  'canvas01-r200-s045.png' 'canvas01-r200-s046.png'
#  'canvas01-r200-s047.png' 'canvas01-r200-s048.png'
#  'canvas01-r200-s049.png' 'canvas01-r200-s050.png'
#  'canvas01-r200-s051.png' 'canvas01-r200-s052.png'
#  'canvas01-r200-s053.png' 'canvas01-r200-s054.png'
#  'canvas01-r200-s055.png' 'canvas01-r200-s056.png'
#  'canvas01-r200-s057.png' 'canvas01-r200-s058.png'
#  'canvas01-r200-s059.png' 'canvas01-r200-s060.png'
#  'canvas01-r200-s061.png' 'canvas01-r200-s062.png'
#  'canvas01-r200-s063.png' 'canvas01-r200-s064.png'
#  'canvas01-r200-s065.png' 'canvas01-r200-s066.png'
#  'canvas01-r200-s067.png' 'canvas01-r200-s068.png'
#  'canvas01-r200-s069.png' 'canvas01-r200-s070.png'
#  'canvas01-r200-s071.png' 'canvas01-r200-s072.png'
#  'canvas01-r200-s073.png' 'canvas01-r200-s074.png'
#  'canvas01-r200-s075.png' 'canvas01-r200-s076.png'
#  'canvas01-r200-s077.png' 'canvas01-r200-s078.png'
#  'canvas01-r200-s079.png' 'canvas01-r200-s080.png'
#  'canvas01-r200-s081.png' 'canvas01-r200-s082.png'
#  'canvas01-r200-s083.png' 'canvas01-r200-s084.png'
#  'canvas01-r200-s085.png' 'canvas01-r200-s086.png'
#  'canvas01-r200-s087.png' 'canvas01-r200-s088.png'
#  'canvas01-r200-s089.png' 'canvas01-r200-s090.png'
#  'canvas01-r200-s091.png' 'canvas01-r200-s092.png'
#  'canvas01-r200-s093.png' 'canvas01-r200-s094.png'
#  'canvas01-r200-s095.png' 'canvas01-r200-s096.png'
#  'canvas01-r200-s097.png' 'canvas01-r200-s098.png'
#  'canvas01-r200-s099.png' 'canvas01-r200-s100.png'
#  'canvas01-r240-s001.png' 'canvas01-r240-s002.png'
#  'canvas01-r240-s003.png' 'canvas01-r240-s004.png'
#  'canvas01-r240-s005.png' 'canvas01-r240-s006.png'
#  'canvas01-r240-s007.png' 'canvas01-r240-s008.png'
#  'canvas01-r240-s009.png' 'canvas01-r240-s010.png'
#  'canvas01-r240-s011.png' 'canvas01-r240-s012.png'
#  'canvas01-r240-s013.png' 'canvas01-r240-s014.png'
#  'canvas01-r240-s015.png' 'canvas01-r240-s016.png'
#  'canvas01-r240-s017.png' 'canvas01-r240-s018.png'
#  'canvas01-r240-s019.png' 'canvas01-r240-s020.png'
#  'canvas01-r240-s021.png' 'canvas01-r240-s022.png'
#  'canvas01-r240-s023.png' 'canvas01-r240-s024.png'
#  'canvas01-r240-s025.png' 'canvas01-r240-s026.png'
#  'canvas01-r240-s027.png' 'canvas01-r240-s028.png'
#  'canvas01-r240-s029.png' 'canvas01-r240-s030.png'
#  'canvas01-r240-s031.png' 'canvas01-r240-s032.png'
#  'canvas01-r240-s033.png' 'canvas01-r240-s034.png'
#  'canvas01-r240-s035.png' 'canvas01-r240-s036.png'
#  'canvas01-r240-s037.png' 'canvas01-r240-s038.png'
#  'canvas01-r240-s039.png' 'canvas01-r240-s040.png'
#  'canvas01-r240-s041.png' 'canvas01-r240-s042.png'
#  'canvas01-r240-s043.png' 'canvas01-r240-s044.png'
#  'canvas01-r240-s045.png' 'canvas01-r240-s046.png'
#  'canvas01-r240-s047.png' 'canvas01-r240-s048.png'
#  'canvas01-r240-s049.png' 'canvas01-r240-s050.png'
#  'canvas01-r240-s051.png' 'canvas01-r240-s052.png'
#  'canvas01-r240-s053.png' 'canvas01-r240-s054.png'
#  'canvas01-r240-s055.png' 'canvas01-r240-s056.png'
#  'canvas01-r240-s057.png' 'canvas01-r240-s058.png'
#  'canvas01-r240-s059.png' 'canvas01-r240-s060.png'
#  'canvas01-r240-s061.png' 'canvas01-r240-s062.png'
#  'canvas01-r240-s063.png' 'canvas01-r240-s064.png'
#  'canvas01-r240-s065.png' 'canvas01-r240-s066.png'
#  'canvas01-r240-s067.png' 'canvas01-r240-s068.png'
#  'canvas01-r240-s069.png' 'canvas01-r240-s070.png'
#  'canvas01-r240-s071.png' 'canvas01-r240-s072.png'
#  'canvas01-r240-s073.png' 'canvas01-r240-s074.png'
#  'canvas01-r240-s075.png' 'canvas01-r240-s076.png'
#  'canvas01-r240-s077.png' 'canvas01-r240-s078.png'
#  'canvas01-r240-s079.png' 'canvas01-r240-s080.png'
#  'canvas01-r240-s081.png' 'canvas01-r240-s082.png'
#  'canvas01-r240-s083.png' 'canvas01-r240-s084.png'
#  'canvas01-r240-s085.png' 'canvas01-r240-s086.png'
#  'canvas01-r240-s087.png' 'canvas01-r240-s088.png'
#  'canvas01-r240-s089.png' 'canvas01-r240-s090.png'
#  'canvas01-r240-s091.png' 'canvas01-r240-s092.png'
#  'canvas01-r240-s093.png' 'canvas01-r240-s094.png'
#  'canvas01-r240-s095.png' 'canvas01-r240-s096.png'
#  'canvas01-r240-s097.png' 'canvas01-r240-s098.png'
#  'canvas01-r240-s099.png' 'canvas01-r240-s100.png'
#  'canvas01-r280-s001.png' 'canvas01-r280-s002.png'
#  'canvas01-r280-s003.png' 'canvas01-r280-s004.png'
#  'canvas01-r280-s005.png' 'canvas01-r280-s006.png'
#  'canvas01-r280-s007.png' 'canvas01-r280-s008.png'
#  'canvas01-r280-s009.png' 'canvas01-r280-s010.png'
#  'canvas01-r280-s011.png' 'canvas01-r280-s012.png'
#  'canvas01-r280-s013.png' 'canvas01-r280-s014.png'
#  'canvas01-r280-s015.png' 'canvas01-r280-s016.png'
#  'canvas01-r280-s017.png' 'canvas01-r280-s018.png'
#  'canvas01-r280-s019.png' 'canvas01-r280-s020.png'
#  'canvas01-r280-s021.png' 'canvas01-r280-s022.png'
#  'canvas01-r280-s023.png' 'canvas01-r280-s024.png'
#  'canvas01-r280-s025.png' 'canvas01-r280-s026.png'
#  'canvas01-r280-s027.png' 'canvas01-r280-s028.png'
#  'canvas01-r280-s029.png' 'canvas01-r280-s030.png'
#  'canvas01-r280-s031.png' 'canvas01-r280-s032.png'
#  'canvas01-r280-s033.png' 'canvas01-r280-s034.png'
#  'canvas01-r280-s035.png' 'canvas01-r280-s036.png'
#  'canvas01-r280-s037.png' 'canvas01-r280-s038.png'
#  'canvas01-r280-s039.png' 'canvas01-r280-s040.png'
#  'canvas01-r280-s041.png' 'canvas01-r280-s042.png'
#  'canvas01-r280-s043.png' 'canvas01-r280-s044.png'
#  'canvas01-r280-s045.png' 'canvas01-r280-s046.png'
#  'canvas01-r280-s047.png' 'canvas01-r280-s048.png'
#  'canvas01-r280-s049.png' 'canvas01-r280-s050.png'
#  'canvas01-r280-s051.png' 'canvas01-r280-s052.png'
#  'canvas01-r280-s053.png' 'canvas01-r280-s054.png'
#  'canvas01-r280-s055.png' 'canvas01-r280-s056.png'
#  'canvas01-r280-s057.png' 'canvas01-r280-s058.png'
#  'canvas01-r280-s059.png' 'canvas01-r280-s060.png'
#  'canvas01-r280-s061.png' 'canvas01-r280-s062.png'
#  'canvas01-r280-s063.png' 'canvas01-r280-s064.png'
#  'canvas01-r280-s065.png' 'canvas01-r280-s066.png'
#  'canvas01-r280-s067.png' 'canvas01-r280-s068.png'
#  'canvas01-r280-s069.png' 'canvas01-r280-s070.png'
#  'canvas01-r280-s071.png' 'canvas01-r280-s072.png'
#  'canvas01-r280-s073.png' 'canvas01-r280-s074.png'
#  'canvas01-r280-s075.png' 'canvas01-r280-s076.png'
#  'canvas01-r280-s077.png' 'canvas01-r280-s078.png'
#  'canvas01-r280-s079.png' 'canvas01-r280-s080.png'
#  'canvas01-r280-s081.png' 'canvas01-r280-s082.png'
#  'canvas01-r280-s083.png' 'canvas01-r280-s084.png'
#  'canvas01-r280-s085.png' 'canvas01-r280-s086.png'
#  'canvas01-r280-s087.png' 'canvas01-r280-s088.png'
#  'canvas01-r280-s089.png' 'canvas01-r280-s090.png'
#  'canvas01-r280-s091.png' 'canvas01-r280-s092.png'
#  'canvas01-r280-s093.png' 'canvas01-r280-s094.png'
#  'canvas01-r280-s095.png' 'canvas01-r280-s096.png'
#  'canvas01-r280-s097.png' 'canvas01-r280-s098.png'
#  'canvas01-r280-s099.png' 'canvas01-r280-s100.png'
#  'canvas01-r320-s001.png' 'canvas01-r320-s002.png'
#  'canvas01-r320-s003.png' 'canvas01-r320-s004.png'
#  'canvas01-r320-s005.png' 'canvas01-r320-s006.png'
#  'canvas01-r320-s007.png' 'canvas01-r320-s008.png'
#  'canvas01-r320-s009.png' 'canvas01-r320-s010.png'
#  'canvas01-r320-s011.png' 'canvas01-r320-s012.png'
#  'canvas01-r320-s013.png' 'canvas01-r320-s014.png'
#  'canvas01-r320-s015.png' 'canvas01-r320-s016.png'
#  'canvas01-r320-s017.png' 'canvas01-r320-s018.png'
#  'canvas01-r320-s019.png' 'canvas01-r320-s020.png'
#  'canvas01-r320-s021.png' 'canvas01-r320-s022.png'
#  'canvas01-r320-s023.png' 'canvas01-r320-s024.png'
#  'canvas01-r320-s025.png' 'canvas01-r320-s026.png'
#  'canvas01-r320-s027.png' 'canvas01-r320-s028.png'
#  'canvas01-r320-s029.png' 'canvas01-r320-s030.png'
#  'canvas01-r320-s031.png' 'canvas01-r320-s032.png'
#  'canvas01-r320-s033.png' 'canvas01-r320-s034.png'
#  'canvas01-r320-s035.png' 'canvas01-r320-s036.png'
#  'canvas01-r320-s037.png' 'canvas01-r320-s038.png'
#  'canvas01-r320-s039.png' 'canvas01-r320-s040.png'
#  'canvas01-r320-s041.png' 'canvas01-r320-s042.png'
#  'canvas01-r320-s043.png' 'canvas01-r320-s044.png'
#  'canvas01-r320-s045.png' 'canvas01-r320-s046.png'
#  'canvas01-r320-s047.png' 'canvas01-r320-s048.png'
#  'canvas01-r320-s049.png' 'canvas01-r320-s050.png'
#  'canvas01-r320-s051.png' 'canvas01-r320-s052.png'
#  'canvas01-r320-s053.png' 'canvas01-r320-s054.png'
#  'canvas01-r320-s055.png' 'canvas01-r320-s056.png'
#  'canvas01-r320-s057.png' 'canvas01-r320-s058.png'
#  'canvas01-r320-s059.png' 'canvas01-r320-s060.png'
#  'canvas01-r320-s061.png' 'canvas01-r320-s062.png'
#  'canvas01-r320-s063.png' 'canvas01-r320-s064.png'
#  'canvas01-r320-s065.png' 'canvas01-r320-s066.png'
#  'canvas01-r320-s067.png' 'canvas01-r320-s068.png'
#  'canvas01-r320-s069.png' 'canvas01-r320-s070.png'
#  'canvas01-r320-s071.png' 'canvas01-r320-s072.png'
#  'canvas01-r320-s073.png' 'canvas01-r320-s074.png'
#  'canvas01-r320-s075.png' 'canvas01-r320-s076.png'
#  'canvas01-r320-s077.png' 'canvas01-r320-s078.png'
#  'canvas01-r320-s079.png' 'canvas01-r320-s080.png'
#  'canvas01-r320-s081.png' 'canvas01-r320-s082.png'
#  'canvas01-r320-s083.png' 'canvas01-r320-s084.png'
#  'canvas01-r320-s085.png' 'canvas01-r320-s086.png'
#  'canvas01-r320-s087.png' 'canvas01-r320-s088.png'
#  'canvas01-r320-s089.png' 'canvas01-r320-s090.png'
#  'canvas01-r320-s091.png' 'canvas01-r320-s092.png'
#  'canvas01-r320-s093.png' 'canvas01-r320-s094.png'
#  'canvas01-r320-s095.png' 'canvas01-r320-s096.png'
#  'canvas01-r320-s097.png' 'canvas01-r320-s098.png'
#  'canvas01-r320-s099.png' 'canvas01-r320-s100.png']

# %%
for i, fname in enumerate(filenames):
        data_ss = data_ss_all[data_ss_all['filename'] == fname]  # Filter data for each k
        # plt.scatter(subset['k'], subset['Smoothness'], label=f'k = {k}',
        #         color=colors[i % len(colors)], marker=markers[i % len(markers)])  # Plot x vs. y
        # plt.plot(subset['k'], subset['Smoothness'], linestyle='-', color=colors[i % len(colors)], linewidth=0.5)
        plt.figure(1)
        plt.rcParams.update({"font.size": 14})
        scatter = plt.scatter(data_ss["Smoothness"], data_ss["Curve structure"], c=data_ss['q'], cmap='gist_rainbow')
        # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
        special_symbols = {0: 'o', 1: 's', 2: '^'}
        for q_value, marker in special_symbols.items():
                subset = data_ss[data_ss['q'] == q_value]
                plt.scatter(subset["Smoothness"], subset["Curve structure"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
                plt.ylim([-1, 1])
        plt.xlim([-1, 1])
        plt.grid(True)
        plt.xlabel('Smoothness')
        plt.ylabel('Curve structure')
        plt.title(f'SCS {images_class}')

#     plt.xlabel('q')  # Label for x-axis
#     plt.ylabel('Smoothness')  # Label for y-axis
#     plt.title('Plot of q vs Smoothness for each k')  # Title of the plot
#     plt.legend()  # Add a legend to distinguish the curves
#     plt.grid(True)  # Optionally add a grid for better readability
#     plt.savefig(f'temp/parameter q/colored_noise_qxSmoothness_function.png')
#     plt.clf() # clears the figure
plt.colorbar(scatter, label='Parameter q')
plt.savefig(f'results/sintorn_dataset/planes/SCS_{images_class}.png', bbox_inches='tight')
plt.show()

# %%
for i, fname in enumerate(filenames):
        data_ss = data_ss_all[data_ss_all['filename'] == fname]  # Filter data for each k
        # plt.scatter(subset['k'], subset['Smoothness'], label=f'k = {k}',
        #         color=colors[i % len(colors)], marker=markers[i % len(markers)])  # Plot x vs. y
        # plt.plot(subset['k'], subset['Smoothness'], linestyle='-', color=colors[i % len(colors)], linewidth=0.5)
        plt.figure(1)
        plt.rcParams.update({"font.size": 14})
        scatter = plt.scatter(data_ss["Weighted Entropy Correct"], data_ss["Weighted Complexity Correct"], c=data_ss['q'], cmap='gist_rainbow')
        # Overlay special symbols for points where data_ss['q'] is 0, 1, or 2
        special_symbols = {0: 'o', 1: 's', 2: '^'}
        for q_value, marker in special_symbols.items():
                subset = data_ss[data_ss['q'] == q_value]
                plt.scatter(subset["Weighted Entropy Correct"], subset["Weighted Complexity Correct"], c='white', edgecolors='black', marker=marker, label=f'q={q_value}')
                plt.ylim([-1, 1])
        plt.xlim([-1, 1])
        plt.grid(True)
        plt.xlabel('Entropy')
        plt.ylabel('Complexity')
        plt.title(f'EC {images_class}')

#     plt.xlabel('q')  # Label for x-axis
#     plt.ylabel('Smoothness')  # Label for y-axis
#     plt.title('Plot of q vs Smoothness for each k')  # Title of the plot
#     plt.legend()  # Add a legend to distinguish the curves
#     plt.grid(True)  # Optionally add a grid for better readability
#     plt.savefig(f'temp/parameter q/colored_noise_qxSmoothness_function.png')
#     plt.clf() # clears the figure
plt.colorbar(scatter, label='Parameter q')
plt.savefig(f'results/sintorn_dataset/planes/EC_{images_class}.png', bbox_inches='tight')
plt.show()

# %%
# data_ss_all.set_index('Date', inplace=True)
data_ss_all.groupby('filename').plot("Smoothness","Curve structure")
# Out:
# filename
# canesugar01-r000-s032.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r000-s044.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r000-s066.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r040-s044.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r040-s046.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r080-s005.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r080-s051.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r080-s073.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r080-s094.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r120-s014.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r200-s034.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r200-s048.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r240-s001.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r240-s017.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r240-s050.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r240-s074.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r280-s017.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r280-s051.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r320-s002.png    Axes(0.125,0.11;0.775x0.77)
# canesugar01-r320-s010.png    Axes(0.125,0.11;0.775x0.77)
# dtype: object
